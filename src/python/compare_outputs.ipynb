# %% [markdown]
# Compares outputs to expected outputs

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr

# %%
colin_triple_rotations = xr.open_dataset('/Users/waldinian/Work/UWyo/Research/Flux Pipeline Project/Platinum_EC/data/alex_tr_tilt_summary.nc')
reference_triple_rotations = xr.open_dataset('/Users/waldinian/Work/UWyo/Research/Flux Pipeline Project/Platinum_EC/data/alex_tr_tilt_summary.nc')

# %%
fig = plt.figure(figsize=(10, 10))

fig.add_subplot(231)
plt.scatter(reference_triple_rotations.Theta, colin_triple_rotations.Theta - reference_triple_rotations.Theta)
plt.plot([0, 2*np.pi], [0, 0], 'k--', lw=0.5)
plt.title('Theta')

fig.add_subplot(232)
plt.scatter(reference_triple_rotations.Phi, colin_triple_rotations.Phi - reference_triple_rotations.Phi)
plt.plot([0, 0.3], [0, 0], 'k--', lw=0.5)
plt.title('Phi')

fig.add_subplot(233)
plt.scatter(reference_triple_rotations.Psi, colin_triple_rotations.Psi - reference_triple_rotations.Psi)
plt.plot([0.002, 0.0023], [0, 0], 'k--', lw=0.5)
plt.title('Psi')

fig.add_subplot(234)
plt.scatter(reference_triple_rotations.U, colin_triple_rotations.U - reference_triple_rotations.U)
# plt.plot([0.002, 0.0023], [0, 0], 'k--', lw=0.5)
plt.title('U')

fig.add_subplot(235)
plt.scatter(reference_triple_rotations.V, colin_triple_rotations.V - reference_triple_rotations.V)
# plt.plot([0.002, 0.0023], [0, 0], 'k--', lw=0.5)
plt.title('V')

fig.add_subplot(236)
plt.scatter(reference_triple_rotations.W, colin_triple_rotations.W - reference_triple_rotations.W)
# plt.plot([0.002, 0.0023], [0, 0], 'k--', lw=0.5)
plt.title('W')
# Out:
# Text(0.5, 1.0, 'W')
